# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)

# %%
data = pd.read_csv('data/clean_train.csv', header=0)
print(data.shape)
print(list(data.columns))
# Out:
# (34872, 16)
# ['id', 'Sex', 'Age', 'high_BP', 'heart_condition_detected_2017', 'married', 'average_blood_sugar', 'BMI', 'smoker_status', 'TreatmentA', 'TreatmentB', 'TreatmentC', 'TreatmentD', 'stroke_in_2018', 'job_status', 'living_status']

# %%
data
# Out:
#           id  Sex   Age  high_BP  heart_condition_detected_2017  married  \
# 0      16053    F  61.0        1                              0        1
# 1       1459    F  30.0        0                              0        0
# 2       7678    F  51.0        1                              0        1
# 3      34943    F  54.0        0                              0        1
# 4      17741    M  27.0        0                              0        0
# 5      26198  NaN   NaN        0                              0        1
# 6       7284    M  63.0        0                              0        1
# 7      10704    M  55.0        0                              1        1
# 8      41988    F  37.0        0                              0        0
# 9      12578    M  49.0        0                              0        1
# 10      6882    F  37.0        0                              0        1
# 11     11141    M  28.0        0                              0        0
# ...

# %%
data['stroke_in_2018'].value_counts()
# Out:
# 0    34220
# 1      652
# Name: stroke_in_2018, dtype: int64

# %%
sns.countplot(x='stroke_in_2018',data=data, palette='hls')
plt.show()

# %%
data.groupby('stroke_in_2018').mean()
# Out:
#                           id        Age   high_BP  \
# stroke_in_2018
# 0               21720.226885  44.756195  0.090532
# 1               22409.075153  71.668203  0.253067
#
#                 heart_condition_detected_2017   married  average_blood_sugar  \
# stroke_in_2018
# 0                                    0.044039  0.637493           108.706444
# 1                                    0.225460  0.894172           133.826098
#
#                       BMI  TreatmentA  TreatmentB  TreatmentC  TreatmentD
# stroke_in_2018
# 0               30.907990    0.195753    0.297279    0.196417    0.193762
# 1               32.251487    0.094595    0.168919    0.141892    0.493243

# %%
cols = ['Sex', 'Age', 'high_BP', 'heart_condition_detected_2017', 'average_blood_sugar', 'BMI']
X = data[cols]
y = data['stroke_in_2018']

import statsmodels.api as sm
logit_model=sm.Logit(y.astype(str),X.astype(str))
result=logit_model.fit()
print(result.summary2())

# data.head(1)
# Out:
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# <ipython-input-13-9bd5c4a8df69> in <module>
#       4
#       5 import statsmodels.api as sm
# ----> 6 logit_model=sm.Logit(y.astype(str),X.astype(str))
#       7 result=logit_model.fit()
#       8 print(result.summary2())
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py in __init__(self, endog, exog, **kwargs)
#     427
#     428     def __init__(self, endog, exog, **kwargs):
# --> 429         super(BinaryModel, self).__init__(endog, exog, **kwargs)
#     430         if (not issubclass(self.__class__, MultinomialModel) and
#     431                 not np.all((self.endog >= 0) & (self.endog <= 1))):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/statsmodels/discrete/discrete_model.py in __init__(self, endog, exog, **kwargs)
#     166     """
# ...

# %%
np.asarray(data)
# Out:
# array([[16053, 'F', 61.0, ..., 0, 'GOVERNMENT', 'REMOTE'],
#        [1459, 'F', 30.0, ..., 0, 'PRIVATE_SECTOR', 'REMOTE'],
#        [7678, 'F', 51.0, ..., 0, 'GOVERNMENT', 'REMOTE'],
#        ...,
#        [37984, 'F', 42.0, ..., 0, 'PRIVATE_SECTOR', 'REMOTE'],
#        [809, 'F', 33.0, ..., 0, 'GOVERNMENT', 'REMOTE'],
#        [15744, 'M', 17.0, ..., 0, 'PRIVATE_SECTOR', 'CITY']], dtype=object)
