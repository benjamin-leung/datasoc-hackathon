# %%
import pandas as pd

df = pd.read_csv('data/train.csv')
df.head(100)
# Out:
#        id sex and age high_BP heart_condition_detected_2017 married  \
# 0   16053       F, 61       1                             0       1
# 1    1459       F, 30       0                             0       0
# 2    7678       F, 51       1                             0       1
# 3   34943       F, 54       0                             0       1
# 4   17741       M, 27       0                             0       0
# 5   26198         NaN     NaN                           NaN       1
# 6    7284       M, 63       0                             0       1
# 7   10704       M, 55       0                             1       1
# 8   41988       F, 37       0                             0       0
# 9   12578       M, 49       0                             0       1
# 10   6882       F, 37       0                             0       1
# 11  11141       M, 28       0                             0       0
# 12  18929       F, 68       0                             0       1
# ...
